# %%
# !pip install mlxtend
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Dataset
dataset = [
['Milk', 'Bread', 'Butter'],
['Bread', 'Butter'],
['Milk', 'Bread'],
['Milk', 'Butter'],
['Bread', 'Butter']
]

# Convert dataset
te = TransactionEncoder()
te_data = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_data, columns=te.columns_)

# Apply Apriori
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)

# Generate rules
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.6)
print("Frequent Itemsets:\n", frequent_itemsets)
print("\nAssociation Rules:\n", rules)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: mlxtend in .\AppData\Roaming\Python\Python314\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in .\AppData\Roaming\Python\Python314\site-packages (from mlxtend) (1.17.0)
# Requirement already satisfied: numpy>=2.3.5 in .\AppData\Roaming\Python\Python314\site-packages (from mlxtend) (2.4.0)
# Requirement already satisfied: pandas>=2.3.3 in .\AppData\Roaming\Python\Python314\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in .\AppData\Roaming\Python\Python314\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in .\AppData\Roaming\Python\Python314\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in .\AppData\Roaming\Python\Python314\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in .\AppData\Roaming\Python\Python314\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\AppData\Roaming\Python\Python314\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\AppData\Roaming\Python\Python314\site-packages (from pandas>=2.3.3->mlxtend) (2025.3)
# Requirement already satisfied: six>=1.5 in .\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in .\AppData\Roaming\Python\Python314\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Frequent Itemsets:
#     support         itemsets
# 0      0.8          (Bread)
# 1      0.8         (Butter)
# 2      0.6           (Milk)
# 3      0.6  (Bread, Butter)
# 4      0.4    (Bread, Milk)
# 5      0.4   (Butter, Milk)
#
# Association Rules:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0     (Bread)    (Butter)                 0.8                 0.8      0.6
# 1    (Butter)     (Bread)                 0.8                 0.8      0.6
# 2      (Milk)     (Bread)                 0.6                 0.8      0.4
# 3      (Milk)    (Butter)                 0.6                 0.8      0.4
#
#    confidence      lift  representativity  leverage  conviction  \
# 0    0.750000  0.937500               1.0     -0.04         0.8
# 1    0.750000  0.937500               1.0     -0.04         0.8
# 2    0.666667  0.833333               1.0     -0.08         0.6
# 3    0.666667  0.833333               1.0     -0.08         0.6
#
#    zhangs_metric  jaccard  certainty  kulczynski
# 0      -0.250000      0.6  -0.250000    0.750000
# 1      -0.250000      0.6  -0.250000    0.750000
# 2      -0.333333      0.4  -0.666667    0.583333
# 3      -0.333333      0.4  -0.666667    0.583333
